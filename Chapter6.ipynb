# %% [markdown]
# <a href="https://colab.research.google.com/github/youngchul-sung/start-tf2-programming/blob/master/Chapter6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import tensorflow as tf

print(tf.__version__)
# Out:
# TensorFlow 2.x selected.
# 2.1.0

# %%
# 그림 6.8 출력 코드. 참고 링크 : https://stackoverflow.com/a/37435090/2689257
import matplotlib.pyplot as plt

image_path = tf.keras.utils.get_file('cat.jpg', 'http://bit.ly/33U6mH9')
image = plt.imread(image_path)

titles = ['RGB Image', 'Red channel', 'Green channel', 'Blue channel']
cmaps = [None, plt.cm.Reds_r, plt.cm.Greens_r, plt.cm.Blues_r]

from numpy import array, zeros_like
def channel(image, color):
    if color not in (0, 1, 2): return image
    c = image[..., color]
    z = zeros_like(c)
    return array([(c, z, z), (z, c, z), (z, z, c)][color]).transpose(1,2,0)
  
colors = range(-1, 3)
fig, axes = plt.subplots(1, 4, figsize=(13,3))
objs = zip(axes, titles, colors)
for ax, title, color in objs:
    ax.imshow(channel(image, color))
    ax.set_title(title)
    ax.set_xticks(())
    ax.set_yticks(())

plt.show()

# %%
# 6.1 Conv2D 레이어 생성 코드
conv1 = tf.keras.layers.Conv2D(kernel_size=(3,3),strides=(2,2),padding='valid' ,filters=16)

# 6.2 MaxPool2D 레이어 생성 코드
pool1 = tf.keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2))

# 6.3 Dropout 레이어 생성 코드
drop1 = tf.keras.layers.Dropout(rate=0.3)

# %%
# 6.4 Fashion MNIST 데이터셋 불러오기 및 정규화
import tensorflow as tf

fashion_mnist = tf.keras.datasets.fashion_mnist
(train_X, train_Y), (test_X, test_Y) = fashion_mnist.load_data()

train_X = train_X / 255.0
test_X = test_X / 255.0

# %%
# 6.5 데이터를 채널을 가진 이미지 형태(3차원)으로 바꾸기
# reshape 이전
print(train_X.shape, test_X.shape)

train_X = train_X.reshape(-1, 28, 28, 1)
test_X = test_X.reshape(-1, 28, 28, 1)

# reshape 이후
print(train_X.shape, test_X.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28)
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %%
# 6.6 데이터 확인
import matplotlib.pyplot as plt
# 전체 그래프의 사이즈를 width=10, height=10 으로 지정합니다.
plt.figure(figsize=(10, 10))
for c in range(16):
    # 4행 4열로 지정한 grid 에서 c+1 번째의 칸에 그래프를 그립니다. 1~16 번째 칸을 채우게 됩니다.
    plt.subplot(4,4,c+1)
    plt.imshow(train_X[c].reshape(28,28), cmap='gray')
    
plt.show()

# train 데이터의 첫번째 ~ 16번째 까지의 라벨을 프린트합니다.
print(train_Y[:16])
# Out:
# [9 0 0 3 0 2 7 2 5 5 0 9 5 5 7 9]

# %%
# 6.7 Fashion MNIST 분류 컨볼루션 신경망 모델 정의
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=16),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=32),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 16)        160
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 32)        4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 22, 22, 64)        18496
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 3,989,642
# Trainable params: 3,989,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 6.8 Google Colab GPU 사양 확인
# !nvidia-smi
# Out:
# Mon Mar  2 07:51:54 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.48.02    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P0    27W /  70W |    297MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# 6.9 Fashion MNIST 분류 컨볼루션 신경망 모델 학습
history = model.fit(train_X, train_Y, epochs=25, validation_split=0.25)

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()

model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/25
# 45000/45000 [==============================] - 10s 228us/sample - loss: 0.4639 - accuracy: 0.8346 - val_loss: 0.4107 - val_accuracy: 0.8517
# Epoch 2/25
# 45000/45000 [==============================] - 7s 166us/sample - loss: 0.3390 - accuracy: 0.8759 - val_loss: 0.3880 - val_accuracy: 0.8587
# Epoch 3/25
# 45000/45000 [==============================] - 7s 165us/sample - loss: 0.2866 - accuracy: 0.8938 - val_loss: 0.3715 - val_accuracy: 0.8729
# Epoch 4/25
# 45000/45000 [==============================] - 7s 165us/sample - loss: 0.2435 - accuracy: 0.9104 - val_loss: 0.3984 - val_accuracy: 0.8689
# Epoch 5/25
# 45000/45000 [==============================] - 7s 164us/sample - loss: 0.2099 - accuracy: 0.9226 - val_loss: 0.4200 - val_accuracy: 0.8743
# Epoch 6/25
# 45000/45000 [==============================] - 8s 168us/sample - loss: 0.1870 - accuracy: 0.9309 - val_loss: 0.4439 - val_accuracy: 0.8689
# Epoch 7/25
# 45000/45000 [==============================] - 8s 168us/sample - loss: 0.1641 - accuracy: 0.9376 - val_loss: 0.5060 - val_accuracy: 0.8699
# Epoch 8/25
# 45000/45000 [==============================] - 7s 166us/sample - loss: 0.1469 - accuracy: 0.9461 - val_loss: 0.5547 - val_accuracy: 0.8616
# Epoch 9/25
# 45000/45000 [==============================] - 7s 166us/sample - loss: 0.1363 - accuracy: 0.9496 - val_loss: 0.6406 - val_accuracy: 0.8630
# Epoch 10/25
# 45000/45000 [==============================] - 7s 167us/sample - loss: 0.1261 - accuracy: 0.9540 - val_loss: 0.5911 - val_accuracy: 0.8635
# Epoch 11/25
# 45000/45000 [==============================] - 8s 167us/sample - loss: 0.1119 - accuracy: 0.9596 - val_loss: 0.6772 - val_accuracy: 0.8617
# Epoch 12/25
# 45000/45000 [==============================] - 8s 167us/sample - loss: 0.1027 - accuracy: 0.9623 - val_loss: 0.7367 - val_accuracy: 0.8667
# Epoch 13/25
# 45000/45000 [==============================] - 8s 167us/sample - loss: 0.0978 - accuracy: 0.9651 - val_loss: 0.8004 - val_accuracy: 0.8619
# Epoch 14/25
# 45000/45000 [==============================] - 8s 168us/sample - loss: 0.0817 - accuracy: 0.9692 - val_loss: 0.8133 - val_accuracy: 0.8601
# Epoch 15/25
# 45000/45000 [==============================] - 8s 168us/sample - loss: 0.0973 - accuracy: 0.9655 - val_loss: 0.9093 - val_accuracy: 0.8650
# Epoch 16/25
# 45000/45000 [==============================] - 7s 165us/sample - loss: 0.0809 - accuracy: 0.9714 - val_loss: 0.9296 - val_accuracy: 0.8592
# Epoch 17/25
# 45000/45000 [==============================] - 7s 165us/sample - loss: 0.0794 - accuracy: 0.9718 - val_loss: 0.9303 - val_accuracy: 0.8635
# Epoch 18/25
# 45000/45000 [==============================] - 7s 166us/sample - loss: 0.0790 - accuracy: 0.9734 - val_loss: 1.0035 - val_accuracy: 0.8637
# Epoch 19/25
# 45000/45000 [==============================] - 7s 166us/sample - loss: 0.0698 - accuracy: 0.9768 - val_loss: 0.9994 - val_accuracy: 0.8631
# Epoch 20/25
# 45000/45000 [==============================] - 7s 166us/sample - loss: 0.0696 - accuracy: 0.9763 - val_loss: 1.1268 - val_accuracy: 0.8648
# Epoch 21/25
# 45000/45000 [==============================] - 7s 166us/sample - loss: 0.0619 - accuracy: 0.9786 - val_loss: 1.1754 - val_accuracy: 0.8636
# Epoch 22/25
# 45000/45000 [==============================] - 8s 168us/sample - loss: 0.0655 - accuracy: 0.9775 - val_loss: 1.1203 - val_accuracy: 0.8657
# Epoch 23/25
# 45000/45000 [==============================] - 8s 168us/sample - loss: 0.0698 - accuracy: 0.9766 - val_loss: 1.1542 - val_accuracy: 0.8625
# Epoch 24/25
# 45000/45000 [==============================] - 8s 167us/sample - loss: 0.0602 - accuracy: 0.9800 - val_loss: 1.2766 - val_accuracy: 0.8627
# Epoch 25/25
# 45000/45000 [==============================] - 7s 165us/sample - loss: 0.0637 - accuracy: 0.9795 - val_loss: 1.2218 - val_accuracy: 0.8611
# [1.2945254623055458, 0.856]

# %%
# 6.10 Fashion MNIST 분류 컨볼루션 신경망 모델 정의 - 풀링 레이어, 드랍아웃 레이어 추가
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=32),
    tf.keras.layers.MaxPool2D(strides=(2,2)),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64),
    tf.keras.layers.MaxPool2D(strides=(2,2)),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               147584
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 241,546
# Trainable params: 241,546
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 6.11 Fashion MNIST 분류 컨볼루션 신경망 모델 학습 - 풀링 레이어, 드랍아웃 레이어 추가
history = model.fit(train_X, train_Y, epochs=25, validation_split=0.25)

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()

model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/25
# 45000/45000 [==============================] - 6s 142us/sample - loss: 0.5282 - accuracy: 0.8081 - val_loss: 0.3675 - val_accuracy: 0.8651
# Epoch 2/25
# 45000/45000 [==============================] - 6s 129us/sample - loss: 0.3587 - accuracy: 0.8711 - val_loss: 0.3362 - val_accuracy: 0.8768
# Epoch 3/25
# 45000/45000 [==============================] - 6s 131us/sample - loss: 0.3179 - accuracy: 0.8848 - val_loss: 0.2939 - val_accuracy: 0.8925
# Epoch 4/25
# 45000/45000 [==============================] - 6s 133us/sample - loss: 0.2905 - accuracy: 0.8942 - val_loss: 0.3081 - val_accuracy: 0.8929
# Epoch 5/25
# 45000/45000 [==============================] - 6s 133us/sample - loss: 0.2688 - accuracy: 0.9018 - val_loss: 0.2874 - val_accuracy: 0.8970
# Epoch 6/25
# 45000/45000 [==============================] - 6s 140us/sample - loss: 0.2516 - accuracy: 0.9076 - val_loss: 0.3054 - val_accuracy: 0.8927
# Epoch 7/25
# 45000/45000 [==============================] - 7s 145us/sample - loss: 0.2365 - accuracy: 0.9127 - val_loss: 0.2977 - val_accuracy: 0.8997
# Epoch 8/25
# 45000/45000 [==============================] - 6s 134us/sample - loss: 0.2259 - accuracy: 0.9176 - val_loss: 0.3215 - val_accuracy: 0.8855
# Epoch 9/25
# 45000/45000 [==============================] - 6s 134us/sample - loss: 0.2136 - accuracy: 0.9213 - val_loss: 0.3141 - val_accuracy: 0.8969
# Epoch 10/25
# 45000/45000 [==============================] - 6s 137us/sample - loss: 0.2016 - accuracy: 0.9260 - val_loss: 0.3114 - val_accuracy: 0.8957
# Epoch 11/25
# 45000/45000 [==============================] - 6s 133us/sample - loss: 0.1957 - accuracy: 0.9277 - val_loss: 0.3113 - val_accuracy: 0.9008
# Epoch 12/25
# 45000/45000 [==============================] - 6s 135us/sample - loss: 0.1874 - accuracy: 0.9285 - val_loss: 0.3419 - val_accuracy: 0.8887
# Epoch 13/25
# 45000/45000 [==============================] - 6s 134us/sample - loss: 0.1814 - accuracy: 0.9317 - val_loss: 0.3513 - val_accuracy: 0.8943
# Epoch 14/25
# 45000/45000 [==============================] - 6s 131us/sample - loss: 0.1737 - accuracy: 0.9353 - val_loss: 0.3596 - val_accuracy: 0.8909
# Epoch 15/25
# 45000/45000 [==============================] - 6s 134us/sample - loss: 0.1639 - accuracy: 0.9384 - val_loss: 0.3596 - val_accuracy: 0.8995
# Epoch 16/25
# 45000/45000 [==============================] - 6s 135us/sample - loss: 0.1649 - accuracy: 0.9381 - val_loss: 0.3689 - val_accuracy: 0.8943
# Epoch 17/25
# 45000/45000 [==============================] - 6s 135us/sample - loss: 0.1570 - accuracy: 0.9415 - val_loss: 0.3899 - val_accuracy: 0.8943
# Epoch 18/25
# 45000/45000 [==============================] - 6s 134us/sample - loss: 0.1555 - accuracy: 0.9435 - val_loss: 0.3631 - val_accuracy: 0.8965
# Epoch 19/25
# 45000/45000 [==============================] - 6s 133us/sample - loss: 0.1485 - accuracy: 0.9444 - val_loss: 0.4121 - val_accuracy: 0.8934
# Epoch 20/25
# 45000/45000 [==============================] - 6s 133us/sample - loss: 0.1480 - accuracy: 0.9440 - val_loss: 0.3930 - val_accuracy: 0.8903
# Epoch 21/25
# 45000/45000 [==============================] - 6s 132us/sample - loss: 0.1406 - accuracy: 0.9475 - val_loss: 0.4289 - val_accuracy: 0.9000
# Epoch 22/25
# 45000/45000 [==============================] - 6s 131us/sample - loss: 0.1409 - accuracy: 0.9473 - val_loss: 0.4324 - val_accuracy: 0.8959
# Epoch 23/25
# 45000/45000 [==============================] - 6s 134us/sample - loss: 0.1367 - accuracy: 0.9501 - val_loss: 0.4869 - val_accuracy: 0.8882
# Epoch 24/25
# 45000/45000 [==============================] - 6s 135us/sample - loss: 0.1312 - accuracy: 0.9518 - val_loss: 0.4609 - val_accuracy: 0.8939
# Epoch 25/25
# 45000/45000 [==============================] - 6s 137us/sample - loss: 0.1389 - accuracy: 0.9491 - val_loss: 0.4462 - val_accuracy: 0.8973
# [0.45038146453797817, 0.8961]

# %%
# 6.12 VGGNet 스타일의 Fashion MNIST 분류 컨볼루션 신경망 모델 정의
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=32, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, padding='valid', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 12, 12, 256)       295168
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               4719104
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 5,240,842
# Trainable params: 5,240,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 6.13 VGGNet 스타일의 Fashion MNIST 분류 컨볼루션 신경망 모델 학습
history = model.fit(train_X, train_Y, epochs=25, validation_split=0.25)

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()

model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/25
# 45000/45000 [==============================] - 13s 290us/sample - loss: 0.5800 - accuracy: 0.7898 - val_loss: 0.3336 - val_accuracy: 0.8755
# Epoch 2/25
# 45000/45000 [==============================] - 12s 263us/sample - loss: 0.3741 - accuracy: 0.8661 - val_loss: 0.2904 - val_accuracy: 0.8881
# Epoch 3/25
# 45000/45000 [==============================] - 12s 265us/sample - loss: 0.3293 - accuracy: 0.8817 - val_loss: 0.2564 - val_accuracy: 0.9063
# Epoch 4/25
# 45000/45000 [==============================] - 12s 265us/sample - loss: 0.3049 - accuracy: 0.8897 - val_loss: 0.2442 - val_accuracy: 0.9083
# Epoch 5/25
# 45000/45000 [==============================] - 12s 265us/sample - loss: 0.2954 - accuracy: 0.8934 - val_loss: 0.2329 - val_accuracy: 0.9143
# Epoch 6/25
# 45000/45000 [==============================] - 12s 269us/sample - loss: 0.2798 - accuracy: 0.8986 - val_loss: 0.2230 - val_accuracy: 0.9193
# Epoch 7/25
# 45000/45000 [==============================] - 12s 264us/sample - loss: 0.2712 - accuracy: 0.9020 - val_loss: 0.2292 - val_accuracy: 0.9131
# Epoch 8/25
# 45000/45000 [==============================] - 12s 265us/sample - loss: 0.2662 - accuracy: 0.9033 - val_loss: 0.2153 - val_accuracy: 0.9213
# Epoch 9/25
# 45000/45000 [==============================] - 12s 264us/sample - loss: 0.2601 - accuracy: 0.9061 - val_loss: 0.2143 - val_accuracy: 0.9222
# Epoch 10/25
# 45000/45000 [==============================] - 12s 263us/sample - loss: 0.2529 - accuracy: 0.9091 - val_loss: 0.2069 - val_accuracy: 0.9240
# Epoch 11/25
# 45000/45000 [==============================] - 12s 267us/sample - loss: 0.2514 - accuracy: 0.9105 - val_loss: 0.2065 - val_accuracy: 0.9253
# Epoch 12/25
# 45000/45000 [==============================] - 12s 264us/sample - loss: 0.2465 - accuracy: 0.9118 - val_loss: 0.2100 - val_accuracy: 0.9244
# Epoch 13/25
# 45000/45000 [==============================] - 12s 265us/sample - loss: 0.2454 - accuracy: 0.9113 - val_loss: 0.2047 - val_accuracy: 0.9262
# Epoch 14/25
# 45000/45000 [==============================] - 12s 264us/sample - loss: 0.2399 - accuracy: 0.9141 - val_loss: 0.2151 - val_accuracy: 0.9217
# Epoch 15/25
# 45000/45000 [==============================] - 12s 264us/sample - loss: 0.2403 - accuracy: 0.9145 - val_loss: 0.2061 - val_accuracy: 0.9271
# Epoch 16/25
# 45000/45000 [==============================] - 12s 270us/sample - loss: 0.2352 - accuracy: 0.9162 - val_loss: 0.2039 - val_accuracy: 0.9244
# Epoch 17/25
# 45000/45000 [==============================] - 12s 269us/sample - loss: 0.2375 - accuracy: 0.9157 - val_loss: 0.2014 - val_accuracy: 0.9271
# Epoch 18/25
# 45000/45000 [==============================] - 12s 266us/sample - loss: 0.2336 - accuracy: 0.9159 - val_loss: 0.2050 - val_accuracy: 0.9273
# Epoch 19/25
# 45000/45000 [==============================] - 12s 265us/sample - loss: 0.2334 - accuracy: 0.9173 - val_loss: 0.2023 - val_accuracy: 0.9255
# Epoch 20/25
# 45000/45000 [==============================] - 12s 265us/sample - loss: 0.2270 - accuracy: 0.9182 - val_loss: 0.2102 - val_accuracy: 0.9287
# Epoch 21/25
# 45000/45000 [==============================] - 12s 266us/sample - loss: 0.2290 - accuracy: 0.9195 - val_loss: 0.2038 - val_accuracy: 0.9273
# Epoch 22/25
# 45000/45000 [==============================] - 12s 264us/sample - loss: 0.2363 - accuracy: 0.9160 - val_loss: 0.2064 - val_accuracy: 0.9267
# Epoch 23/25
# 45000/45000 [==============================] - 12s 262us/sample - loss: 0.2270 - accuracy: 0.9195 - val_loss: 0.2113 - val_accuracy: 0.9264
# Epoch 24/25
# 45000/45000 [==============================] - 12s 263us/sample - loss: 0.2259 - accuracy: 0.9194 - val_loss: 0.2109 - val_accuracy: 0.9267
# Epoch 25/25
# 45000/45000 [==============================] - 12s 265us/sample - loss: 0.2240 - accuracy: 0.9205 - val_loss: 0.2033 - val_accuracy: 0.9295
# [0.217588098859787, 0.9232]

# %%
# 6.14 Image Augmentation 데이터 표시
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# 이 ImageDataGenerator 코드 부분은 다음 링크에서 참조했습니다. 
# https://github.com/franneck94/MNIST-Data-Augmentation/blob/master/mnist.py
# rotation, zoom, shift, flip 등을 지정합니다.
image_generator = ImageDataGenerator(
            rotation_range=10,
            zoom_range=0.10,
            shear_range=0.5,
            width_shift_range=0.10,
            height_shift_range=0.10,
            horizontal_flip=True,
            vertical_flip=False)

augment_size = 100

x_augmented = image_generator.flow(np.tile(train_X[0].reshape(28*28),100).reshape(-1,28,28,1), np.zeros(augment_size), batch_size=augment_size, shuffle=False).next()[0]

# 새롭게 생성된 이미지 표시
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for c in range(100):
    plt.subplot(10,10,c+1)
    plt.axis('off')
    plt.imshow(x_augmented[c].reshape(28,28), cmap='gray')
plt.show()

# %%
# 6.15 Image Augmentation
image_generator = ImageDataGenerator(
            rotation_range=10,
            zoom_range=0.10,
            shear_range=0.5,
            width_shift_range=0.10,
            height_shift_range=0.10,
            horizontal_flip=True,
            vertical_flip=False)

augment_size = 30000

randidx = np.random.randint(train_X.shape[0], size=augment_size)
x_augmented = train_X[randidx].copy()
y_augmented = train_Y[randidx].copy()
x_augmented = image_generator.flow(x_augmented, np.zeros(augment_size),
                                   batch_size=augment_size, shuffle=False).next()[0]

# 원래 데이터인 x_train 에 Image Augmentation 된 x_augmented 를 추가합니다.
train_X = np.concatenate((train_X, x_augmented))
train_Y = np.concatenate((train_Y, y_augmented))

print(train_X.shape)
# Out:
# (90000, 28, 28, 1)

# %%
# 6.16 VGGNet style 네트워크 + Image Augmentation 학습
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=32, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, padding='valid', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

history = model.fit(train_X, train_Y, epochs=25, validation_split=0.25)

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()

model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Train on 67500 samples, validate on 22500 samples
# Epoch 1/25
# 67500/67500 [==============================] - 19s 277us/sample - loss: 0.5736 - accuracy: 0.7909 - val_loss: 0.5565 - val_accuracy: 0.7864
# Epoch 2/25
# 67500/67500 [==============================] - 18s 265us/sample - loss: 0.3765 - accuracy: 0.8645 - val_loss: 0.4913 - val_accuracy: 0.8160
# Epoch 3/25
# 67500/67500 [==============================] - 18s 264us/sample - loss: 0.3378 - accuracy: 0.8780 - val_loss: 0.4812 - val_accuracy: 0.8216
# Epoch 4/25
# 67500/67500 [==============================] - 18s 265us/sample - loss: 0.3209 - accuracy: 0.8847 - val_loss: 0.4317 - val_accuracy: 0.8384
# Epoch 5/25
# 67500/67500 [==============================] - 18s 265us/sample - loss: 0.3078 - accuracy: 0.8896 - val_loss: 0.4449 - val_accuracy: 0.8358
# Epoch 6/25
# 67500/67500 [==============================] - 18s 264us/sample - loss: 0.2995 - accuracy: 0.8923 - val_loss: 0.4360 - val_accuracy: 0.8324
# Epoch 7/25
# 67500/67500 [==============================] - 18s 265us/sample - loss: 0.2972 - accuracy: 0.8939 - val_loss: 0.4215 - val_accuracy: 0.8426
# Epoch 8/25
# 67500/67500 [==============================] - 18s 264us/sample - loss: 0.2874 - accuracy: 0.8980 - val_loss: 0.3997 - val_accuracy: 0.8520
# Epoch 9/25
# 67500/67500 [==============================] - 18s 264us/sample - loss: 0.2830 - accuracy: 0.8989 - val_loss: 0.4032 - val_accuracy: 0.8498
# Epoch 10/25
# 67500/67500 [==============================] - 18s 266us/sample - loss: 0.2740 - accuracy: 0.9029 - val_loss: 0.3779 - val_accuracy: 0.8599
# Epoch 11/25
# 67500/67500 [==============================] - 18s 267us/sample - loss: 0.2765 - accuracy: 0.9009 - val_loss: 0.4048 - val_accuracy: 0.8558
# Epoch 12/25
# 67500/67500 [==============================] - 18s 266us/sample - loss: 0.2749 - accuracy: 0.9012 - val_loss: 0.4102 - val_accuracy: 0.8487
# Epoch 13/25
# 67500/67500 [==============================] - 18s 263us/sample - loss: 0.2710 - accuracy: 0.9033 - val_loss: 0.3745 - val_accuracy: 0.8626
# Epoch 14/25
# 67500/67500 [==============================] - 18s 265us/sample - loss: 0.2732 - accuracy: 0.9027 - val_loss: 0.3946 - val_accuracy: 0.8538
# Epoch 15/25
# 67500/67500 [==============================] - 18s 263us/sample - loss: 0.2703 - accuracy: 0.9046 - val_loss: 0.4169 - val_accuracy: 0.8492
# Epoch 16/25
# 67500/67500 [==============================] - 18s 262us/sample - loss: 0.2688 - accuracy: 0.9038 - val_loss: 0.3860 - val_accuracy: 0.8553
# Epoch 17/25
# 67500/67500 [==============================] - 18s 266us/sample - loss: 0.2708 - accuracy: 0.9034 - val_loss: 0.3856 - val_accuracy: 0.8550
# Epoch 18/25
# 67500/67500 [==============================] - 18s 263us/sample - loss: 0.2659 - accuracy: 0.9041 - val_loss: 0.3769 - val_accuracy: 0.8608
# Epoch 19/25
# 67500/67500 [==============================] - 18s 264us/sample - loss: 0.2633 - accuracy: 0.9073 - val_loss: 0.3877 - val_accuracy: 0.8530
# Epoch 20/25
# 67500/67500 [==============================] - 18s 265us/sample - loss: 0.2668 - accuracy: 0.9057 - val_loss: 0.3837 - val_accuracy: 0.8585
# Epoch 21/25
# 67500/67500 [==============================] - 18s 263us/sample - loss: 0.2638 - accuracy: 0.9075 - val_loss: 0.4060 - val_accuracy: 0.8525
# Epoch 22/25
# 67500/67500 [==============================] - 18s 263us/sample - loss: 0.2608 - accuracy: 0.9079 - val_loss: 0.3872 - val_accuracy: 0.8573
# Epoch 23/25
# 67500/67500 [==============================] - 18s 264us/sample - loss: 0.2624 - accuracy: 0.9069 - val_loss: 0.4099 - val_accuracy: 0.8492
# Epoch 24/25
# 67500/67500 [==============================] - 18s 265us/sample - loss: 0.2620 - accuracy: 0.9091 - val_loss: 0.3969 - val_accuracy: 0.8617
# Epoch 25/25
# 67500/67500 [==============================] - 18s 262us/sample - loss: 0.2587 - accuracy: 0.9082 - val_loss: 0.4014 - val_accuracy: 0.8568
# [0.21701574553251265, 0.9237]
